# %%
x=int(input("Enter a number: "))
if(x%2==0 and x>0):
    print(f"The number {x} is even and Positive.")
elif(x%2==0 and x<0):
    print(f"The number {x} is odd and Negative.")
elif(x%2!=0 and x>0):
    print(f"The number {x} is odd and Positive.")
elif(x%2!=0 and x<0):
    print(f"The number {x} is odd and Negative.")
else:
    print(f"The number {x} is zero.")
# Out:
# The number -23 is odd and Negative.

# %% [markdown]
# Question 2

# %%
k=int(input("Enter a number: "))
if(k%2==0 and k%3==0 and k>0):
    print(f"The number {k} is divisible by 2 and 3 and Positive.")
elif(k%2==0 and k%3==0 and k<0):
    print(f"The number {k} is divisible by 2 and 3 and Negative.")
elif(k%2==0 and k%3!=0 and k>0):
    print(f"The number {k} is divisible by 2 and not divisible by 3 and Positive.")
elif(k%2==0 and k%3!=0 and k<0):
    print(f"The number {k} is divisible by 2 and not divisible by 3 and Negative.")
elif(k%2!=0 and k%3==0 and k>0):
    print(f"The number {k} is not divisible by 2 and divisible by 3 and Positive.")
elif(k%2!=0 and k%3==0 and k<0):
    print(f"The number {k} is not divisible by 2 and  divisible by 3 and Negative.")
elif(k%2!=0 and k%3!=0 and k>0):
    print(f"The number {k} is not divisible by 2 and 3 and Positive.")
elif(k%2!=0 and k%3!=0 and k<0):
    print(f"The number {k} is not divisible by 2 and 3 and Negative.")
else:
    print(f"The number {k} is Zero.")
# Out:
# The number -90 is divisible by 2 and 3 and Negative.

# %% [markdown]
# Question 3

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))
if(a<b and a<c):
    print(f"The number {a} is the Less than among {a}, {b}, and {c}.")
elif(b<a and b<c):
    print(f"The number {b} is the Less than among {a}, {b}, and {c}.")
else:
    print(f"The number {c} is the Less than among {a}, {b}, and {c}.")
# Out:
# The number -1234 is the Less than among 90, -456, and -1234.

# %% [markdown]
# Question 4

# %%
x=int(input("Enter a number: "))
square=x*x
print(f"{square} is the Square of this {x} number. ")
# Out:
# 8100 is the Square of this -90 number.

# %%
y=int(input("Enter a number: "))
result=0
counter=0
while(counter<y):
    result=result+y
    counter=counter+1
print(f"{result} is the Square of this {y} number. ")
# Out:
# 81 is the Square of this 9 number.

# %% [markdown]
# Question 5

# %%
list=[1,2,3,"Bird",4,5,"Animal"]
sum = 0
for item in list:
    if isinstance(item, (int, float)):
        sum += item

print("Sum =", sum)
# Out:
# Sum = 15

# %%
list = [10, "Apple", 20, "Banana", 30]
total = 0

for item in list:
    try:
        total += item
    except:
        continue

print("Sum =", total)
# Out:
# Sum = 60

# %% [markdown]
# Question 6

# %%
my_list = [10, None, 20, None, 30, 40]

total = 0

for item in my_list:
    if item is None:
        continue
    total += item

print("Sum =", total)
# Out:
# Sum = 100

# %% [markdown]
# Separate different data type list

# %%
i_list = [10, "Apple", 20, "Banana", 30.678, 40.123, "Orange", 50,[3,4]]
int_list = [i for i in i_list if type(i) == int]
float_list = [i for i in i_list if type(i) == float]
string=[i for i in i_list if type(i) == str]
print("Integer List:", int_list)
print("Float List:", float_list)
print("String List:", string)
"""separate the values given in list based on data types and create separate lists for each data type."""
# Out:
# Integer List: [10, 20, 50]
# Float List: [30.678, 40.123]
# String List: ['Apple', 'Banana', 'Orange']
# 'separate the values given in list based on data types and create separate lists for each data type.'

# %% [markdown]
# Question 7

# %%
numbers = [10, 20, 30, 40, 50]

target = 30

for num in numbers:
    if num == target:
        print("Target found:", num)
        break
    print(num)
# Out:
# 10
# 20
# Target found: 30

# %% [markdown]
# Question 8

# %%
for i in range(10, 20, 2):
    print(i)
# Out:
# 10
# 12
# 14
# 16
# 18

# %%
fruits = ["Apple", "Banana", "Mango"]

for i in range(len(fruits)):
    print(i, fruits[i])
# Out:
# 0 Apple
# 1 Banana
# 2 Mango

# %% [markdown]
# Question 9

# %%
A = {1, 2, 3, 4}
B = set([3, 4, 5, 6])

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
print("Symmetric Difference:", A ^ B)
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 5, 6}

# %% [markdown]
# Question 10

# %%
A = {1, 2, 3}
B = {3, 4, 5}

A.update(B)
print("After update:", A)

A = {1, 2, 3, 4}
B = {3, 4, 5}

A.intersection_update(B)
print("After intersection_update:", A)

X = {1, 2}
Y = {1, 2, 3, 4}

print("Subset:", X.issubset(Y))
print("Superset:", Y.issuperset(X))
# Out:
# After update: {1, 2, 3, 4, 5}
# After intersection_update: {3, 4}
# Subset: True
# Superset: True

# %%
A = {1,2,3}
B = {3,2,1}

print(A == B)
# Out:
# True

# %% [markdown]
# Question 11

# %%
numbers = [1,2,3,4,5,6]

result = []

for num in numbers:
    if num % 2 == 0:
        result.append(num * 2)

print(result)
# Out:
# [4, 8, 12]
