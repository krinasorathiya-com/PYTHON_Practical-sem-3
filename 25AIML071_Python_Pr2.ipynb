# %%
b=[1,2,3,4,5]
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(b)
# Out:
# 5

# %%
b.append(2)
b.append(2)
b.append(7)
print(b)
# Out:
# [1, 2, 3, 4, 5, 6, 2, 2, 7]

# %%
def add_numbers(a,c):
    """ This function takes two numbers as input and returns their sum."""
    return a+c

# %%
add_numbers?
# Out:
# Signature: add_numbers(a, c)
# Docstring: <no docstring>
# File:      c:\users\krina\appdata\local\temp\ipykernel_24296\216528273.py
# Type:      function

# %%
add_numbers??
# Out:
# Signature: add_numbers(a, c)
# Docstring: <no docstring>
# Source:
# def add_numbers(a,c):
#     return a+c
# File:      c:\users\krina\appdata\local\temp\ipykernel_24296\216528273.py
# Type:      function

# %%
# %run add.py
# Out:
# 8.461538461538462

# %%
result
# Out:
# 8.461538461538462

# %%
result
# Out:
# 8.461538461538462

# %%
pwd
# Out:
# 'c:\\Users\\Krina\\OneDrive\\PYTHON_Practical sem 3'

# %%
# %pwd
# Out:
# 'c:\\Users\\Krina\\OneDrive\\PYTHON_Practical sem 3'

# %%
pip install numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/numpy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/numpy/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NameResolutionError("HTTPSConnection(host='pypi.org', port=443): Failed to resolve 'pypi.org' ([Errno 11001] getaddrinfo failed)")': /simple/numpy/
# ...

# %%
d=np.random.randn(100,100)
# %timeit np.dot(d,d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 d=np.random.randn(100,100)
#       2 get_ipython().run_line_magic('timeit', 'np.dot(d,d)')
#
# NameError: name 'np' is not defined

# %%
pip install numpy
# Out:
# Could not fetch URL https://pypi.org/simple/numpy/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/numpy/ (Caused by SSLError(SSLCertVerificationError('A certificate chain processed, but terminated in a root certificate which is not trusted by the trust provider.'))) - skipping
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError('A certificate chain processed, but terminated in a root certificate which is not trusted by the trust provider.'))': /simple/numpy/
# ...
