# %%
b=[1,2,3,4,5]
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(b)
# Out:
# 5

# %%
b.append(2)
b.append(2)
b.append(7)
print(b)
# Out:
# [1, 2, 3, 4, 5, 6, 2, 2, 7]

# %%
def add_numbers(a,c):
    """ This function takes two numbers as input and returns their sum."""
    return a+c

# %%
add_numbers?
# Out:
# Signature: add_numbers(a, c)
# Docstring: <no docstring>
# File:      c:\users\krina\appdata\local\temp\ipykernel_24296\216528273.py
# Type:      function

# %%
add_numbers??
# Out:
# Signature: add_numbers(a, c)
# Docstring: <no docstring>
# Source:
# def add_numbers(a,c):
#     return a+c
# File:      c:\users\krina\appdata\local\temp\ipykernel_24296\216528273.py
# Type:      function

# %%
# %run add.py
# Out:
# 8.461538461538462

# %%
result
# Out:
# 8.461538461538462

# %%
result
# Out:
# 8.461538461538462
