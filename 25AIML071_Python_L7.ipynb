# %%
f=open("index.txt",'a')
f.write("New Content\n")
f.close()

# %%
f=open("my_self.txt",'r')
print(f.read())
# Out:
# Hello!
#
# My name is Krina.
# I am learning programming and AI/ML.
# I enjoy practicing C++, Java, Python, and DSA.
#
# Thank you!

# %%
f=open("file.txt",'x')

# %% [markdown]
# w is create new file caleed if is not exist

# %%
f=open("myfile.txt",'w')

# %%
with open("myfile.txt","w")as file:
    file.write("Today I learned about file handling in python.\n")
    file.write("It is very useful for reading and writing files.\n")

# %%
with open("file.txt","r")as file:
    lines = file.readlines()
    for i, line in enumerate(lines,start=1):
        print(f"Line (i): {line.strip()}")

# %%
with open("my_file.txt", "a") as file:
    file.write("I will practice more to become confident.\n")

# %%
with open("my_file.txt", "r") as file:
    text = file.read()
    words = text.split()
    print("Total words:", len(words))
# Out:
# Total words: 7

# %% [markdown]
# Count Wors in a file

# %%
with open("index.txt","r")as file:
    text=file.read()
    words=text.split()
    print("Total Words: ",words)
# Out:
# Total Words:  ['5.', 'Why', 'would', 'graphs', 'be', 'used', 'to', 'represent', 'data?', 'Answer:', 'To', 'capture', 'complex', 'relationships', 'Explanation:', 'Graphs', 'represent', 'data', 'as', 'vertices', '(nodes)', 'and', 'edges', '(connections),', 'making', 'them', 'ideal', 'for', 'modeling', 'networks,', 'maps,', 'and', 'social', 'media', 'relationships.New', 'Question', 'New', 'Question', 'New', 'Question', 'New', 'Question', 'New', 'Content']

# %% [markdown]
# Copy Contents to Another file

# %%
with open("my_file.txt", "r") as source:
    content = source.read()

with open("backup_notes.txt", "w") as target:
    target.write(content)

# %% [markdown]
# Count Lines,Words,Characters

# %%
with open("my_file.txt", "r") as file:
    lines = file.readlines()

num_lines = len(lines)
num_words = sum(len(line.split()) for line in lines)
num_chars = sum(len(line) for line in lines)

print("Lines:", num_lines)
print("Words:", num_words)
print("Characters:", num_chars)
# Out:
# Lines: 2
# Words: 14
# Characters: 84

# %% [markdown]
# Remove Blank Lines

# %%
with open("index.txt","r")as infile,open("cleaned_notes.txt","w")as outfile:
    for line in infile:
        if line.strip():
            outfile.write(line)

# %% [markdown]
# Delete file and OS commands

# %%
import os
os.remove("file.txt")

# %% [markdown]
# Delete the file

# %%
if os.path.exists("file.txt"):
    os.remove("file.txt")
else:
    print("File not Found.")
# Out:
# File not Found.

# %% [markdown]
# Rename a file

# %%
import os
os.rename("my_self.txt","krina.txt")
print("File renamed Successfully.")
# Out:
# File renamed Successfully.

# %% [markdown]
# salary=[20000,30000,45000,35000,21000,40000]
#
# #1.filter the salaries greater than 30000 using lambda function
#
# #2.show top 5% salaries from the list using lambda function
#
# #3.show square roots of salaries from the file,rounded to integer using lambda function

# %%
salary = [20000, 30000, 45000, 35000, 21000, 40000]

greater = list(filter(lambda x: x > 30000, salary))
print("Salaries greater than 30000:", greater)
# Out:
# Salaries greater than 30000: [45000, 35000, 40000]

# %%
print(sorted(salary,reverse=True)[:1])
# Out:
# [45000]
# [45000]

# %%
salary=list(map(lambda i:round(i**(0.5)),salary))
salary
# Out:
# [141, 173, 212, 187, 145, 200]
