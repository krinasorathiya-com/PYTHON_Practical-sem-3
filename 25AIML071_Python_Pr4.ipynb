# %%
(50-5)*4
# Out:
# 180

# %%
2//4
# Out:
# 0

# %%
50-5*4
# Out:
# 30

# %%
34/17
# Out:
# 2.0

# %%
-23+3
# Out:
# -20

# %%
4**2
# Out:
# 16

# %%
20%4
# Out:
# 0

# %%
56//12
# Out:
# 4

# %%
2+2
# Out:
# 4

# %%
x=8
y=3
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
print(x**(1/y))
# Out:
# 11
# 5
# 24
# 2.6666666666666665
# 2
# 2
# 512
# 2.0

# %%
square_root = 81**(1/2)
print(square_root)
# Out:
# 9.0

# %%
square_root = 729**(1/3)
print(square_root)
# Out:
# 8.999999999999998

# %%
4*3.5+1 #int 4 and 1 converted to float implicitly and then the operation is performed
# Out:
# 15.0

# %%
rate=9.5/100
principal=975
interest=principal*rate
interest
# Out:
# 92.625

# %%
n=349.78
n
# Out:
# 349.78

# %%
total=principal+ _
total
# Out:
# 1324.78

# %%
round(_,2)
# Out:
# 1324.78

# %%
x=78
y=90
z=-87
max(x,y,z)
# Out:
# 90

# %%
f=int(input("Enter the temperature in Fahrenheit: "))
c=(f-32)*5/9
print("Temperature in Celsius is: ",c)
# Out:
# Temperature in Celsius is:  112.22222222222223

# %%
c=int(input("Enter the temperature in Celsius: "))
f=c*9/5+32
print("Temperature in Fahrenheit is: ",f)
# Out:
# Temperature in Fahrenheit is:  653.0
