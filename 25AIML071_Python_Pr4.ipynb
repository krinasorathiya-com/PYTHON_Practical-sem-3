# %%
2//4
# Out:
# 0

# %%
50-5*4
# Out:
# 30

# %%
34/17
# Out:
# 2.0

# %%
-23+3
# Out:
# -20

# %%
4**2
# Out:
# 16

# %%
20%4
# Out:
# 0

# %%
56//12
# Out:
# 4

# %%
2+2
# Out:
# 4

# %%
x=8
y=3
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
print(x**(1/y))
# Out:
# 11
# 5
# 24
# 2.6666666666666665
# 2
# 2
# 512
# 2.0

# %%
square_root = 81**(1/2)
print(square_root)
# Out:
# 9.0

# %%
square_root = 729**(1/3)
print(square_root)
# Out:
# 8.999999999999998
