# %%
print("first_code")
# Out:
# first_code

# %%
print("Hello_world")
# Out:
# Hello_world

# %% [markdown]
# THIS IS HEADING  1.

# %%
print("this is my file.\nit is basic of python")
# Out:
# this is my file.
# it is basic of python

# %%
print("Krina's class")
print("Krina's\tclass")
# Out:
# Krina's class
# Krina's	class

# %%
print(''' hello 
      python is a programming language that lets you work quickly
    '''  )
# Out:
#  hello
#     python is a programming language that lets you work quickly

# %%
"A car and A truck"
# Out:
# 'A car and A truck'

# %%
a=0
b=0
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
print("Addition : ",a+b)
# Out:
# Addition :  79

# %%
a=34
b=67
c=a+b
print("Addition of {} and {} is {}".format(a,b,c))
print("Addition (string) : "+str(a)+" + "+str(b)+" = "+str(c))
# Out:
# Addition of 34 and 67 is 101
# Addition (string) : 34 + 67 = 101

# %%
age =input("age:")
"your age is " + age
# Out:
# 'your age is 23'

# %%
name = "Krina"
age = 18

print("My name is %s and my age is %d" % (name, age))
# Out:
# My name is Krina and my age is 18

# %%
print(3*'Car \n' +4* 'Bus \n')
# Out:
# Car
# Car
# Car
# Bus
# Bus
# Bus
# Bus

# %%
print("Samay is {} and {} boy. He loves to {} games {}".format('a good','charming','play','football'))
print("Samay completed {0:.10f} percent of assignment".format(99.56))
print("Samay completed {0:0.0f} percent of assignment".format(99.36))
# Out:
# Samay is a good and charming boy. He loves to play games football
# Samay completed 99.5600000000 percent of assignment
# Samay completed 99 percent of assignment

# %%
print(r'c:\dir\new')
# Out:
# c:\dir\new

# %%
string="Python is a programming language that lets you work quickly and integrate systems more effectively."
print(string[0:11])
print(string[12:29])
print(string[:50])
print(string[12:13])
print(string[4:])
print(string[-80])
print(string[-70:-50])
print(len(string))
# Out:
# Python is a
# programming langu
# Python is a programming language that lets you wor
# p
# on is a programming language that lets you work quickly and integrate systems more effectively.
# m
# age that lets you wo
# 99

# %%
string="Python"
print(string[0:6])
print(string[0:6:2])
print(string[0:6:3])
# Out:
# Python
# Pto
# Ph
