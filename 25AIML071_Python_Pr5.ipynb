# %%
Fish_List=['Bowfin','Cod','Herring','Ray','Salmon']

# %%
Fish_List
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon']

# %% [markdown]
# List.append()

# %%
Fish_List.append('Wahoo')

# %%
Fish_List
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon', 'Wahoo']

# %% [markdown]
# List.insert()

# %%
Fish_List.insert(4,'Hiphip')

# %%
Fish_List
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Hiphip', 'Salmon', 'Wahoo']

# %% [markdown]
# list.extend()

# %%
Fish_w_List=['Walleye','Weakfish','whiting','wow']
Fish_List.extend(Fish_w_List)

# %%
Fish_w_List
# Out:
# ['Walleye', 'Weakfish', 'whiting', 'wow']

# %% [markdown]
# list.pop()

# %%
pop_Fish=Fish_List.pop(5)

# %%
pop_Fish
# Out:
# 'Salmon'

# %%
Fish_List
# Out:
# ['Bowfin',
#  'Cod',
#  'Herring',
#  'Ray',
#  'Hiphip',
#  'Wahoo',
#  'Walleye',
#  'Weakfish',
#  'whiting',
#  'wow']

# %% [markdown]
# list.remove()

# %%
Fish_List.remove('Bowfin')

# %%
Fish_List
# Out:
# ['Cod',
#  'Herring',
#  'Ray',
#  'Hiphip',
#  'Wahoo',
#  'Walleye',
#  'Weakfish',
#  'whiting',
#  'wow']

# %% [markdown]
# list.index()

# %%
Fish_List.index('wow')
# Out:
# 8

# %%
Fish_List.index('How')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 Fish_List.index('How')
#
# ValueError: list.index(x): x not in list

# %% [markdown]
# list.copy()

# %%
Fish_List2=Fish_List.copy()

# %%
Fish_List2
# Out:
# ['Cod',
#  'Herring',
#  'Ray',
#  'Hiphip',
#  'Wahoo',
#  'Walleye',
#  'Weakfish',
#  'whiting',
#  'wow']

# %%
Fish_List2 = Fish_List

Fish_List2.append("Beautiful")

print(Fish_List)
print(Fish_List2)
# Out:
# ['Cod', 'Herring', 'Ray', 'Hiphip', 'Walleye', 'Weakfish', 'whiting', 'wow', 'Beautiful']
# ['Cod', 'Herring', 'Ray', 'Hiphip', 'Walleye', 'Weakfish', 'whiting', 'wow', 'Beautiful']

# %%
print(Fish_List)
# Out:
# ['Cod', 'Herring', 'Ray', 'Hiphip', 'Wahoo', 'Walleye', 'Weakfish', 'whiting', 'wow']

# %% [markdown]
# list.reverse()

# %%
Fish_List2.reverse()
print(Fish_List2)
# Out:
# ['Beautiful', 'wow', 'whiting', 'Weakfish', 'Walleye', 'Wahoo', 'Hiphip', 'Ray', 'Herring', 'Cod']

# %% [markdown]
# add string in list

# %%
Fish_List2=Fish_List+['Cod','Cod']
Fish_List2
# Out:
# ['Cod',
#  'Herring',
#  'Ray',
#  'Hiphip',
#  'Wahoo',
#  'Walleye',
#  'Weakfish',
#  'whiting',
#  'wow',
#  'Cod',
#  'Cod']

# %% [markdown]
# Count

# %%
Fish_List2.count('Cod')
# Out:
# 3

# %% [markdown]
# list.sort()

# %%
Fish_List.sort(reverse=True)

# %%
Fish_age=[2,3,4,5,6,7,1,6,3,2]

# %%
Fish_age.sort(reverse=True)

# %%
Fish_age
# Out:
# [7, 6, 6, 5, 4, 3, 3, 2, 2, 1]

# %%
Fish_age.count(6)
# Out:
# 2

# %%
Fish_agecopy=Fish_age.copy()
Fish_agecopy.sort()
Fish_age
# Out:
# [7, 6, 6, 5, 4, 3, 3, 2, 2, 1]

# %%
Fish_agecopy
# Out:
# [1, 2, 2, 3, 3, 4, 5, 6, 6, 7]

# %% [markdown]
# list.clear()

# %%
Fish_age.clear()

# %%
Fish_age
# Out:
# []

# %%
Fish_List
# Out:
# ['wow',
#  'whiting',
#  'Weakfish',
#  'Walleye',
#  'Wahoo',
#  'Ray',
#  'Hiphip',
#  'Herring',
#  'Cod']

# %%
Fish_List.clear()

# %%
Fish_List
# Out:
# []

# %% [markdown]
# BUILT-IN FUNCTIONS

# %%
#isinstance
test_int=5
test_list=[1,2,3]

print("Is test_int integer? :",(isinstance(test_int,int)))
print("Is test_int string? :"+str(isinstance(test_int,str)))
print("Is test_list integer? :"+str(isinstance(test_list,int)))
print("Is test_list list? :"+str(isinstance(test_list,list)))
# Out:
# Is test_int integer? : True
# Is test_int string? :False
# Is test_list integer? :False
# Is test_list list? :True

# %%
isinstance(test_list,(int,set))
# Out:
# False

# %% [markdown]
# ENUMERATE

# %%
x=('apple','Pineapple','grapes')
a="cherry"
y=enumerate(x)
z=enumerate(a)

print("Return Type: ",type(y))
print(enumerate(x))
# Out:
# Return Type:  <class 'enumerate'>
# ...

# %%
print(list(enumerate(x)))
print(list(z))
# Out:
# [(0, 'apple'), (1, 'Pineapple'), (2, 'grapes')]
# [(0, 'c'), (1, 'h'), (2, 'e'), (3, 'r'), (4, 'r'), (5, 'y')]

# %%
l1=["eat","sleep","repeat"]

for ele in enumerate(l1):
    print(ele)
for count, ele in enumerate(l1, 100):
    print(count, ele)
for count, ele in enumerate(l1):
    print(count)
    print(ele)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')
# 100 eat
# 101 sleep
# 102 repeat
# 0
# eat
# 1
# sleep
# 2
# repeat

# %%
student=["John","Alice","Bob"]
student
# Out:
# ['John', 'Alice', 'Bob']

# %%
list1=[2,4,4,6,2,8,6,9,3,7,7]
un = set(list1)
print((un))
# Out:
# {2, 3, 4, 6, 7, 8, 9}

# %%
list1=[2,4,4,6,2,8,6,9,3,7,7]
type(list1)
# Out:
# list

# %%
list2={2, 3, 4, 6, 7, 8, 9}
type(list2)
# Out:
# set

# %%
dil={"roll no.":[1,2,3,4,5],"Name" :["k","r","i","n","a"]}
type(dil)
# Out:
# dict

# %%
lists=[11,4,2,1,11,45,78,23]

# %%
list=[1,2,3,4,5]
list[2]=30
list
# Out:
# [1, 2, 30, 4, 5]

# %%
tuple=(1,2,3,4,5)

# %%
tuple[0]=100
tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 2
#       1 tuple=(1,2,3,4,5)
# ----> 2 tuple[0]=100
#       3 tuple
#
# TypeError: 'tuple' object does not support item assignment

# %%
tuple.append(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 tuple.append(2)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tuple[2].extend([6,7,8])
tuple
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 tuple[2].extend([6,7,8])
#       2 tuple
#
# AttributeError: 'int' object has no attribute 'extend'

# %%
lista=[1,'food',[4,5]]
lista
# Out:
# [1, 'food', [4, 5]]

# %%
lista[2]
# Out:
# [4, 5]

# %%
lista[2]=(5,6)

# %%
lista
# Out:
# [1, 'food', (5, 6)]
