# %%
Fish_List=['Bowfin','Cod','Herring','Ray','Salmon']

# %%
Fish_List
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon']

# %% [markdown]
# List.append()

# %%
Fish_List.append('Wahoo')

# %%
Fish_List
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Salmon', 'Wahoo']

# %% [markdown]
# List.insert()

# %%
Fish_List.insert(4,'Hiphip')

# %%
Fish_List
# Out:
# ['Bowfin', 'Cod', 'Herring', 'Ray', 'Hiphip', 'Salmon', 'Wahoo']

# %% [markdown]
# list.extend()

# %%
Fish_w_List=['Walleye','Weakfish','whiting','wow']
Fish_List.extend(Fish_w_List)

# %%
Fish_w_List
# Out:
# ['Walleye', 'Weakfish', 'whiting', 'wow']

# %% [markdown]
# list.pop()

# %%
pop_Fish=Fish_List.pop(5)

# %%
pop_Fish
# Out:
# 'Wahoo'

# %%
Fish_List
# Out:
# ['Bowfin',
#  'Cod',
#  'Herring',
#  'Ray',
#  'Hiphip',
#  'Walleye',
#  'Weakfish',
#  'whiting',
#  'wow']

# %% [markdown]
# list.remove()

# %%
Fish_List.remove('Bowfin')

# %%
Fish_List
# Out:
# ['Cod', 'Herring', 'Ray', 'Hiphip', 'Walleye', 'Weakfish', 'whiting', 'wow']

# %% [markdown]
# list.index()

# %%
Fish_List.index('wow')
# Out:
# 7

# %%
Fish_List.index('Wahoo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 Fish_List.index('Wahoo')
#
# ValueError: list.index(x): x not in list

# %% [markdown]
# list.copy()

# %%
Fish_list=Fish_List.copy()

# %%
Fish_list
# Out:
# ['Cod', 'Herring', 'Ray', 'Hiphip', 'Walleye', 'Weakfish', 'whiting', 'wow']
