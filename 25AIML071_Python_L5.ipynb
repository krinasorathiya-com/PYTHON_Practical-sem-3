# %%
strings =['I','am','girl','People']
uniqueLength ={len(x)for x in strings}
uniqueLength
# Out:
# {1, 2, 4, 6}

# %%
loc_mapping={val : index for  index,val in enumerate(strings)}
loc_mapping
# Out:
# {'I': 0, 'am': 1, 'girl': 2, 'People': 3}

# %%
name_data=[['John','Emily','Micheal','engineer'],['elephant','javier','natalia']]

# %%
names_2e=[]
for names in name_data:
    two_es =[name for  name in names if name.count('e')>=2]
    names_2e.extend(two_es)
names_2e
# Out:
# ['engineer', 'elephant']

# %%
for names in name_data:
    for i in names:
        if i.count("e")>=2:
            print(i,":",i.count("e"))
# Out:
# engineer : 3
# elephant : 2
