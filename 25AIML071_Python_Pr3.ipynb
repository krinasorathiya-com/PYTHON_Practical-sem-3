# %%
pi=3
radius=11
area=pi*(radius**2)

# %%
area
# Out:
# 363

# %%
radius=14
area=pi*(radius**2)
area
# Out:
# 588

# %%
radius=14
area
# Out:
# 363

# %%
a =5; b =4.5

# %%
isinstance(a, (float))
# Out:
# False

# %%
isinstance(a,(int,float))
# Out:
# True
