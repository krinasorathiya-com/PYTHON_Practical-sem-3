# %% [markdown]
# Variable and Assignment

# %%
pi=3
radius=11
area=pi*(radius**2)

# %%
area
# Out:
# 363

# %%
radius=14
area=pi*(radius**2)
area
# Out:
# 588

# %%
radius=14
area
# Out:
# 363

# %% [markdown]
# Dynamic Reference and Strong Type

# %%
a =5; b =4.5

# %%
isinstance(a, (float))
# Out:
# False

# %%
isinstance(a,(int,float))
# Out:
# True

# %% [markdown]
# Attributes and Methods

# %% [markdown]
# Duck typing

# %%
s='Krina'
f=4

# %%
for i in s:
    print(i)
# Out:
# K
# r
# i
# n
# a

# %%
f=[1,2,3]
for i in f:
    print(i)
# Out:
# 1
# 2
# 3
