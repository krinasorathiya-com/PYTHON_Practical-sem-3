# %% [markdown]
# Date and Time

# %%
from datetime import datetime

dt = datetime.now()

dt.strftime("%m/%d/%y %H %M")
# Out:
# '07/22/26 15 45'

# %%
from datetime import datetime

dt = datetime.strptime('20210323 143025', '%Y%m%d %H%M%S')
print(dt)
# Out:
# 2021-03-23 14:30:25

# %%
dt2 = datetime(2026, 4, 11, 21, 30)
delta = dt2 - dt
delta
# Out:
# datetime.timedelta(days=1845, seconds=25175)

# %%
type(delta)
# Out:
# datetime.timedelta

# %%
dt
# Out:
# datetime.datetime(2021, 3, 23, 14, 30, 25)

# %%
dt + delta
# Out:
# datetime.datetime(2026, 4, 11, 21, 30)

# %%
from datetime import datetime

dt = datetime.now()
print(dt.strftime('%d/%m/%Y %U %H:%M:%S'))
# Out:
# 22/07/2026 29 15:56:05

# %%
dt.strftime('%F')
# Out:
# '2026-07-22'

# %% [markdown]
# Control Flow

# %%
x=45
if x%2==0:
    print("Even")
else:
    print("Odd")
print('Done With Condition')
# Out:
# Odd
# Done With Condition

# %%
x=int(input("Enter Integer Number:"))
if x%2==0:
    if x%3==0:
        print("Divide by both 2 and 3.")
    else:
        print("Divide by 2 and not by 3.")
elif x%3==0:
    print("Divide by 3 and not by 2.")
else:
    print("Not divide by 2 and 3.")
# Out:
# Not divide by 2 and 3.

# %% [markdown]
# Branching Programs
